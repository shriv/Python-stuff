# %% [markdown]
# Writing a live report
# ==========================
#
# 'Modern' version of a laboratory notebook that includes figures, code, websites and even video!
# ---------------------------

# %% [markdown]
# Inline Graphs
# -----------------

# %%
## IN TERMINAL ##
#ipython notebook --pylab inline

## IN IPYTHON NOTBOOK CELL ##
#%pylab inline

# %%
x = numpy.arange(0,100,1)
y = x**2

plot(x,y)

# %% [markdown]
# Images
# ---------

# %%
from IPython.display import Image
Image(filename='/home/shrividya/graph.png')

# %%
matplotlib.rcParams['figure.figsize'] = (20,10)
import Image as pilImage # PIL's Image class
## RAMAN LINEWIDTH FROM PAPER: Tang and Herman PRB 43 (1991) p2299 ##

im = pilImage.open("/home/shrividya/Tang_Ge_linewidth_vs_T.png")
sub1 = pylab.subplot(221)
imshow(array(im))
pylab.axis('off')

im = pilImage.open("/home/shrividya/Tang_Si_linewidth_vs_T.png")
sub2 = pylab.subplot(222)
imshow(array(im))
pylab.axis('off')
# Out:
# (-0.5, 779.5, 520.5, -0.5)

# %% [markdown]
# LaTeX
# -------------

# %% [markdown]
# Can print inline LaTeX $\exp(\frac{-E_{act}}{k_{B}T})$

# %%
from IPython.display import Latex
Latex(r"""$\exp(\frac{-E_{act}}{k_{B}T})$""")
# Out:
# $\exp(\frac{-E_{act}}{k_{B}T})$

# %% [markdown]
# Youtube Videos
# ---------------

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('iwVvqwLDsJo')
# Out:
#             <iframe
#                 width="400"
#                 height="300"
#                 src="http://www.youtube.com/embed/iwVvqwLDsJo"
#                 frameborder="0"
#                 allowfullscreen
#             ></iframe>

# %% [markdown]
# Websites
# -------------

# %%
from IPython.display import HTML
HTML('<iframe src=http://en.wikipedia.org/ ' 'width=650,heigth=650>')
# Out:
# <iframe src=http://en.wikipedia.org/ width=650,heigth=650>
